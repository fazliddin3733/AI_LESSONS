# %% [markdown]
# Data types

# %%
ism = "Dilshod"
yosh = 25
is_student = True
boy=1.75
print(type(ism))
print(type(yosh))
print(type(is_student))
print(type(boy))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'bool'>
# <class 'float'>

# %% [markdown]
# Tog'ri burchakli uchburchakni gipatenuzasini topish.

# %%
from cmath import sqrt
a=int(input(" a asosi= "))
b=int(input(" b asosi= "))
c=sqrt(a**2+b**2)
print(c)
# Out:
# (5+0j)

# %% [markdown]
# Conditions.
# 3 ta sonni taqqoslash

# %%
a=int(input(" a sonni kiriting = "))
b=int(input(" b sonni kiriting = "))
c=int(input(" c sonni kiriting = "))
if a>b and a>c:
    print('Eng katta son ',a)
elif b>a and b>c:
    print('Eng katta son ',b)
elif c>a and c>b:
    print('Eng katta son ',c)
else:
    print('Barchasi teng')
# Out:
# Eng katta son  7

# %%
#ballga qarab baxo qoyish
ball = int(input("Ballni kiriting: "))

if ball < 0 or ball > 100:
    print("Noto'g'ri ball kiritildi")
elif ball >= 90:
    print("Baho: A")
elif ball >= 80:
    print("Baho: B")
elif ball >= 70:
    print("Baho: C")
elif ball >= 60:
    print("Baho: D")
else:
    print("Baho: F")
# Out:
# Baho: C
