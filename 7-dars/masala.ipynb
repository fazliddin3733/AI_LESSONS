# %% [markdown]
# Foydalanuvchi n sonini kiritsin. 1 dan n gacha bo'lgan barcha sonlar yig'indisini hisoblang.

# %%
n=int(input('son kiriting'))
yigindi=0
for i in range(1,n+1):
    yigindi+=i
print("Yig'indi:",yigindi)
# Out:
# Yig'indi: 6

# %% [markdown]
# Foydalanuvchi n sonini kiritsin. 1 dan n gacha bo'lgan barcha juft sonlarning yig'indisini toping.

# %%
n=int(input('son kiriting'))
yigindi=0
for i in range(0,n+1,2):
    yigindi+=i
print("Yig'indi",yigindi)
# Out:
# Yig'indi 12

# %% [markdown]
# Foydalanuvchi n sonini kiritsin. 1 dan n gacha bo'lgan sonlarning kvadratini chiqaring.

# %%
n=int(input('son kiriting'))
for i in range(1,n+1):
    print(i**2)
# Out:
# 1
# 4
# 9
# 16

# %% [markdown]
# Foydalanuvchi n sonini kiritsin. 1 dan n gacha bo'lgan sonlardan faqat 5 ga karrali sonlarni chiqaring.

# %%
n=int(input('son kiriting '))
for i in range(1,n+1):
    if i%5==0:
        print(i)
# Out:
# 5
# 10
# 15
# 20

# %% [markdown]
# Foydalanuvchi n sonini kiritsin. n marta "Salom" so'zini ekranga chiqaring.

# %%
n=int(input('son kiriting '))
for i in range(1,n+1):
    print('Salom')
# Out:
# Salom
# Salom
# Salom
# Salom
# Salom
# Salom
# Salom
# Salom
# Salom
# Salom

# %% [markdown]
# Foydalanuvchi n sonini kiritsin. 1 dan n gacha bo'lgan sonlar ichida 3 ga ham, 5 ga ham bo'linadigan sonlarni chiqaring.

# %%
n=int(input('son kiriting'))
for i in range(1,n+1):
    if i%3==0 and i%5==0:
        print(i)
# Out:
# 15

# %% [markdown]
# Foydalanuvchi n sonini kiritsin. n dan 1 gacha bo'lgan sonlarni kamayish tartibida chiqaring.

# %%
n=int(input('son kiriting'))
for i in range(n,0,-1):
    print(i)
# Out:
# 5
# 4
# 3
# 2
# 1

# %% [markdown]
# Foydalanuvchi n sonini kiritsin. 1 dan n gacha bo'lgan toq sonlar yig'indisini toping.

# %%
n=int(input('son kiriting'))
yigindi=0
for i in range(1,n+1,2):
    yigindi +=i
print("Yig'indi:",yigindi)
# Out:
# Yig'indi: 9
