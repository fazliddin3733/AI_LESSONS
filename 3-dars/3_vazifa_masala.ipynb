# %%
# Imtixondan o'tishni nazorat qilish uchun  condition tuzing
# Pasport olish uchun condition tuzing

# %%
baxo=int(input("Baxoni kiriting : "))
if baxo==5:
    print("Imtixondan a'lo o'tdi")
elif baxo==4:
    print(" Imtihondan yahshi o'tdi")
elif baxo==3:
    print(" Imtihondan qoniqarli o'tdi")
else:
    print("O'ta olmadi")
# Out:
# Imtixondan a'lo o'tdi

# %%
yosh=int(input("yoshni kiriting : "))
if yosh>=16:
    print("Passport olish mumkin")
else:
    print("Passport yoshiga to'lmagan")
# Out:
# Passport olish mumkin
